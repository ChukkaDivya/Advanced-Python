# %%
import math

# %%
math.factorial(5)
# Out:
# 120

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.ceil(7.5)
# Out:
# 8

# %%
math.sqrt(5)
# Out:
# 2.23606797749979

# %%
import math as m

# %%
m.sqrt(4)
# Out:
# 2.0

# %%
from math import pow

# %%
pow(4,3)
# Out:
# 64.0

# %%
from math import *

# %%
factorial(4)
# Out:
# 24

# %%
import random

# %%
random.random()#random float value between 0 and 1
# Out:
# 0.26709293304061954

# %%
random.choice([10,20,60,40])#given list
# Out:
# 40

# %%
random.randint(1,10)#random integers
# Out:
# 9

# %%
random.uniform(2,5)#random float
# Out:
# 4.3227363176817795

# %%
import random as ran

# %%
ran.choice([10,205,40])
# Out:
# 205

# %%
from random import uniform

# %%
uniform(2,8)
# Out:
# 7.317323910085019

# %%
from random import *

# %%
random()
# Out:
# 0.5912140274598795

# %%
import datetime

# %%
datetime.date.today()
# Out:
# datetime.date(2025, 12, 24)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 12, 24, 15, 18, 3, 410980)

# %%
datetime.datetime.utcnow()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_18508\194642955.py:1: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   datetime.datetime.utcnow()
# datetime.datetime(2025, 12, 24, 9, 48, 53, 558007)

# %%
import datetime as dt

# %%
dt.date.today()
# Out:
# datetime.date(2025, 12, 24)

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 12, 24, 15, 20, 9, 80584)

# %%
from datetime import *

# %%
date.today()
# Out:
# datetime.date(2025, 12, 24)

# %%
datetime.now(UTC)
# Out:
# datetime.datetime(2025, 12, 24, 9, 55, 4, 258714, tzinfo=datetime.timezone.utc)
